# %% [markdown]
# ### Import required Libraries

# %%
import nltk
import re
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /home/vatsal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/vatsal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/vatsal/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Read the text and apply Preprocessing

# %% [markdown]
# ### Read the text file

# %%
file = open('./sommerville.txt', 'r', encoding='utf-8')
T1 = file.read()

# %% [markdown]
# ### Apply the preprocessing

# %%
# Remove Footer
T1 = re.sub('.* 4/4/06 .*\n', '', T1)
T1 = re.sub('[ ]*••[ ]*••\n', '', T1)

# Remove Header
T1 = re.sub('[0-9]+[ ]+Chapter.*\n', '', T1)
T1 = re.sub('[0-9]+.[0-9]+ ■.*[0-9]+\n', '', T1)
T1 = re.sub('Chapter [0-9]+ ■.*[0-9]+\n', '', T1)

# Remove all heading from the Text
T1 = re.sub(r'\d+(\.\d+)*\.\d+.*\n', '', T1)

# Remove Chapter Title
T1 = re.sub('[0-9]+\n[a-zA-Z ]+\n', '', T1)

# Join broken words
T1 = re.sub(r'-\n\s*', '', T1)

#Removing punctuations
punctuations = '''!()-[]{};:'"\,<>./‘’?“”@#$%^&*_~■'''
cleantext = ""
for char in T1:
    if char not in punctuations:
        cleantext = cleantext + char

T1 = cleantext

# Remove tables 
arr = T1.split('\n')

allLines = []

idx = 0

for i in range(0, len(arr)):
  # Split each line into columns based on groups of spaces
  temp = re.split(r'\s{2,}', arr[i])
  if len(temp) <= 2:
    allLines.insert(idx, temp)
    idx += 1

finalText = ''
for k in allLines: 
  if (len(k) > 1):
    finalText += ' ' + k[1].lower()

finalText[:2500]
# Out:
# '  objectives the objectives of this chapter are to introduce software engineering and to provide a framework for understanding the rest of the book when you have read this chapter you will understand what software engineering is and why it is important know the answers to key questions that provide an introduction to software engineering understand some ethical and professional issues that are important for software engineers contents   virtually all countries now depend on complex computerbased systems national infrastructures and utilities rely on computerbased systems and most electrical products include a computer and controlling software industrial manufacturing and distribution is completely computerised as is the financial system therefore producing and maintaining software costeffectively is essential for the functioning of national and international economies software engineering is an engineering discipline whose focus is the costeffective development of highquality software systems software is abstract and intangible it is not constrained by materials or governed by physical laws or by manufacturing processes in some ways this simplifies software engineering as there are no physical limitations on the potential of software however this lack of natural constraints means that software can easily become extremely complex and hence very difficult to understand the notion of software engineering was first proposed in 1968 at a conference held to discuss what was then called the software crisis this software crisis resulted directly from the introduction of new computer hardware based on integrated circuits their power made hitherto unrealisable computer applications a feasible proposition the resulting software was orders of magnitude larger and more complex than previous software systems early experience in building these systems showed that informal software development was not good enough major projects were sometimes years late the software cost much more than predicted was unreliable was difficult to maintain and performed poorly software development was in crisis hardware costs were tumbling whilst software costs were rising rapidly new techniques and methods were needed to control the complexity inherent in large software systems these techniques have become part of software engineering and are now widely used however as our ability to produce software has increased so too has the complexity of the software systems that we need new technologie'

# %% [markdown]
# ## Create WordCloud with stopwords

# %%
# We don't apply tokenization here because the library used here requires a string
# Creating a wordcloud before removing StopWords
wordcloud = WordCloud(stopwords={}, background_color='black').generate(finalText)

# Plotting the wordcloud
plt.figure(figsize = (10,10), facecolor = 'black') 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 3) 
plt.show()

# %% [markdown]
# ## Tokenize the text

# %%
#Tokenizing the text
tokens = nltk.word_tokenize(finalText)
tokens
# Out:
# ['objectives',
#  'the',
#  'objectives',
#  'of',
#  'this',
#  'chapter',
#  'are',
#  'to',
#  'introduce',
#  'software',
#  'engineering',
#  'and',
#  'to',
#  'provide',
#  'a',
#  'framework',
#  'for',
#  'understanding',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'book',
#  'when',
#  'you',
#  'have',
#  'read',
#  'this',
#  'chapter',
#  'you',
#  'will',
#  'understand',
#  'what',
#  'software',
#  'engineering',
#  'is',
#  'and',
#  'why',
#  'it',
#  'is',
#  'important',
#  'know',
#  'the',
#  'answers',
#  'to',
#  'key',
#  'questions',
#  'that',
#  'provide',
#  'an',
#  'introduction',
#  'to',
#  'software',
#  'engineering',
#  'understand',
#  'some',
#  'ethical',
#  'and',
#  'professional',
#  'issues',
#  'that',
#  'are',
#  'important',
#  'for',
#  'software',
#  'engineers',
#  'contents',
#  'virtually',
#  'all',
#  'countries',
#  'now',
#  'depend',
#  'on',
#  'complex',
#  'computerbased',
#  'systems',
#  'national',
#  'infrastructures',
#  'and',
#  'utilities',
#  'rely',
#  'on',
#  'computerbased',
#  'systems',
#  'and',
#  'most',
#  'electrical',
#  'products',
#  'include',
#  'a',
#  'computer',
#  'and',
#  'controlling',
#  'software',
#  'industrial',
#  'manufacturing',
#  'and',
#  'distribution',
#  'is',
#  'completely',
#  'computerised',
#  'as',
#  'is',
#  'the',
#  'financial',
#  'system',
#  'therefore',
#  'producing',
#  'and',
#  'maintaining',
#  'software',
#  'costeffectively',
#  'is',
#  'essential',
#  'for',
#  'the',
#  'functioning',
#  'of',
#  'national',
#  'and',
#  'international',
#  'economies',
#  'software',
#  'engineering',
#  'is',
#  'an',
#  'engineering',
#  'discipline',
#  'whose',
#  'focus',
#  'is',
#  'the',
#  'costeffective',
#  'development',
#  'of',
#  'highquality',
#  'software',
#  'systems',
#  'software',
#  'is',
#  'abstract',
#  'and',
#  'intangible',
#  'it',
#  'is',
#  'not',
#  'constrained',
#  'by',
#  'materials',
#  'or',
#  'governed',
#  'by',
#  'physical',
#  'laws',
#  'or',
#  'by',
#  'manufacturing',
#  'processes',
#  'in',
#  'some',
#  'ways',
#  'this',
#  'simplifies',
#  'software',
#  'engineering',
#  'as',
#  'there',
#  'are',
#  'no',
#  'physical',
#  'limitations',
#  'on',
#  'the',
#  'potential',
#  'of',
#  'software',
#  'however',
#  'this',
#  'lack',
#  'of',
#  'natural',
#  'constraints',
#  'means',
#  'that',
#  'software',
#  'can',
#  'easily',
#  'become',
#  'extremely',
#  'complex',
#  'and',
#  'hence',
#  'very',
#  'difficult',
#  'to',
#  'understand',
#  'the',
#  'notion',
#  'of',
#  'software',
#  'engineering',
#  'was',
#  'first',
#  'proposed',
#  'in',
#  '1968',
#  'at',
#  'a',
#  'conference',
#  'held',
#  'to',
#  'discuss',
#  'what',
#  'was',
#  'then',
#  'called',
#  'the',
#  'software',
#  'crisis',
#  'this',
#  'software',
#  'crisis',
#  'resulted',
#  'directly',
#  'from',
#  'the',
#  'introduction',
#  'of',
#  'new',
#  'computer',
#  'hardware',
#  'based',
#  'on',
#  'integrated',
#  'circuits',
#  'their',
#  'power',
#  'made',
#  'hitherto',
#  'unrealisable',
#  'computer',
#  'applications',
#  'a',
#  'feasible',
#  'proposition',
#  'the',
#  'resulting',
#  'software',
#  'was',
#  'orders',
#  'of',
#  'magnitude',
#  'larger',
#  'and',
#  'more',
#  'complex',
#  'than',
#  'previous',
#  'software',
#  'systems',
#  'early',
#  'experience',
#  'in',
#  'building',
#  'these',
#  'systems',
#  'showed',
#  'that',
#  'informal',
#  'software',
#  'development',
#  'was',
#  'not',
#  'good',
#  'enough',
#  'major',
#  'projects',
#  'were',
#  'sometimes',
#  'years',
#  'late',
#  'the',
#  'software',
#  'cost',
#  'much',
#  'more',
#  'than',
#  'predicted',
#  'was',
#  'unreliable',
#  'was',
#  'difficult',
#  'to',
#  'maintain',
#  'and',
#  'performed',
#  'poorly',
#  'software',
#  'development',
#  'was',
#  'in',
#  'crisis',
#  'hardware',
#  'costs',
#  'were',
#  'tumbling',
#  'whilst',
#  'software',
#  'costs',
#  'were',
#  'rising',
#  'rapidly',
#  'new',
#  'techniques',
#  'and',
#  'methods',
#  'were',
#  'needed',
#  'to',
#  'control',
#  'the',
#  'complexity',
#  'inherent',
#  'in',
#  'large',
#  'software',
#  'systems',
#  'these',
#  'techniques',
#  'have',
#  'become',
#  'part',
#  'of',
#  'software',
#  'engineering',
#  'and',
#  'are',
#  'now',
#  'widely',
#  'used',
#  'however',
#  'as',
#  'our',
#  'ability',
#  'to',
#  'produce',
#  'software',
#  'has',
#  'increased',
#  'so',
#  'too',
#  'has',
#  'the',
#  'complexity',
#  'of',
#  'the',
#  'software',
#  'systems',
#  'that',
#  'we',
#  'need',
#  'new',
#  'technologies',
#  'resulting',
#  'from',
#  'the',
#  'convergence',
#  'of',
#  'computers',
#  'and',
#  'communication',
#  'systems',
#  'and',
#  'complex',
#  'graphical',
#  'user',
#  'interfaces',
#  'place',
#  'new',
#  'demands',
#  'on',
#  'software',
#  'engineers',
#  'as',
#  'many',
#  'companies',
#  'still',
#  'do',
#  'not',
#  'apply',
#  'software',
#  'engineering',
#  'techniques',
#  'effectively',
#  'too',
#  'many',
#  'projects',
#  'still',
#  'produce',
#  'software',
#  'that',
#  'is',
#  'unreliable',
#  'delivered',
#  'late',
#  'and',
#  'over',
#  'budget',
#  'i',
#  'think',
#  'that',
#  'we',
#  'have',
#  'made',
#  'tremendous',
#  'progress',
#  'since',
#  '1968',
#  'and',
#  'that',
#  'the',
#  'development',
#  'of',
#  'software',
#  'engineering',
#  'has',
#  'markedly',
#  'improved',
#  'our',
#  'software',
#  'we',
#  'have',
#  'a',
#  'much',
#  'better',
#  'understanding',
#  'of',
#  'the',
#  'activities',
#  'involved',
#  'in',
#  'software',
#  'development',
#  'we',
#  'have',
#  'developed',
#  'effective',
#  'methods',
#  'of',
#  'software',
#  'specification',
#  'design',
#  'and',
#  'implementation',
#  'new',
#  'notations',
#  'and',
#  'tools',
#  'reduce',
#  'the',
#  'effort',
#  'required',
#  'to',
#  'produce',
#  'large',
#  'and',
#  'complex',
#  'systems',
#  'we',
#  'know',
#  'now',
#  'that',
#  'there',
#  'is',
#  'no',
#  'single',
#  'ideal',
#  'approach',
#  'to',
#  'software',
#  'engineering',
#  'the',
#  'wide',
#  'diversity',
#  'of',
#  'different',
#  'types',
#  'of',
#  'systems',
#  'and',
#  'organisations',
#  'that',
#  'use',
#  'these',
#  'systems',
#  'means',
#  'that',
#  'we',
#  'need',
#  'a',
#  'diversity',
#  'of',
#  'approaches',
#  'to',
#  'software',
#  'development',
#  'however',
#  'fundamental',
#  'notions',
#  'of',
#  'process',
#  'and',
#  'system',
#  'organisation',
#  'underlie',
#  'all',
#  'of',
#  'these',
#  'techniques',
#  'and',
#  'these',
#  'are',
#  'the',
#  'essence',
#  'of',
#  'software',
#  'engineering',
#  'software',
#  'engineers',
#  'can',
#  'be',
#  'rightly',
#  'proud',
#  'of',
#  'their',
#  'achievements',
#  'without',
#  'complex',
#  'software',
#  'we',
#  'would',
#  'not',
#  'have',
#  'explored',
#  'space',
#  'would',
#  'not',
#  'have',
#  'the',
#  'internet',
#  'and',
#  'modern',
#  'telecommunications',
#  'and',
#  'all',
#  'forms',
#  'of',
#  'travel',
#  'would',
#  'be',
#  'more',
#  'dangerous',
#  'and',
#  'expensive',
#  'software',
#  'engineering',
#  'has',
#  'contributed',
#  'a',
#  'great',
#  'deal',
#  'and',
#  'i',
#  'am',
#  'convinced',
#  'that',
#  'as',
#  'the',
#  'discipline',
#  'matures',
#  'its',
#  'contributions',
#  'in',
#  'the',
#  '21st',
#  'century',
#  'will',
#  'be',
#  'even',
#  'greater',
#  'this',
#  'section',
#  'is',
#  'designed',
#  'to',
#  'answer',
#  'some',
#  'fundamental',
#  'questions',
#  'about',
#  'software',
#  'engineering',
#  'and',
#  'to',
#  'give',
#  'you',
#  'some',
#  'impression',
#  'of',
#  'my',
#  'views',
#  'of',
#  'the',
#  'discipline',
#  'the',
#  'format',
#  'that',
#  'i',
#  'have',
#  'used',
#  'here',
#  'is',
#  'the',
#  'faq',
#  'frequently',
#  'asked',
#  'questions',
#  'list',
#  'this',
#  'approach',
#  'is',
#  'commonly',
#  'used',
#  'in',
#  'internet',
#  'newsgroups',
#  'to',
#  'provide',
#  'newcomers',
#  'with',
#  'answers',
#  'to',
#  'frequently',
#  'asked',
#  'questions',
#  'i',
#  'think',
#  'that',
#  'it',
#  'is',
#  'a',
#  'very',
#  'effective',
#  'way',
#  'to',
#  'give',
#  'a',
#  'succinct',
#  'introduction',
#  'to',
#  'the',
#  'subject',
#  'of',
#  'software',
#  'engineering',
#  'figure',
#  'many',
#  'people',
#  'equate',
#  'the',
#  'term',
#  'software',
#  'with',
#  'computer',
#  'programs',
#  'however',
#  'i',
#  'prefer',
#  'a',
#  'broader',
#  'definition',
#  'where',
#  'software',
#  'is',
#  'not',
#  'just',
#  'the',
#  'programs',
#  'but',
#  'also',
#  'all',
#  'associated',
#  'documentation',
#  'and',
#  'configuration',
#  'data',
#  'that',
#  'is',
#  'needed',
#  'to',
#  'make',
#  'these',
#  'programs',
#  'operate',
#  'correctly',
#  'a',
#  'software',
#  'system',
#  'usually',
#  'consists',
#  'of',
#  'a',
#  'number',
#  'of',
#  'separate',
#  'programs',
#  'configuration',
#  'files',
#  'which',
#  'are',
#  'used',
#  'to',
#  'set',
#  'up',
#  'these',
#  'programs',
#  'system',
#  'documentation',
#  'which',
#  'describes',
#  'the',
#  'structure',
#  'of',
#  'the',
#  'system',
#  'and',
#  'user',
#  'documentation',
#  'which',
#  'explains',
#  'how',
#  'to',
#  'use',
#  'the',
#  'system',
#  'and',
#  'web',
#  'sites',
#  'for',
#  'users',
#  'to',
#  'download',
#  'recent',
#  'product',
#  'information',
#  'software',
#  'engineers',
#  'are',
#  'concerned',
#  'with',
#  'developing',
#  'software',
#  'products',
#  'ie',
#  'software',
#  'which',
#  'can',
#  'be',
#  'sold',
#  'to',
#  'a',
#  'customer',
#  'there',
#  'are',
#  'two',
#  'fundamental',
#  'types',
#  'of',
#  'software',
#  'product',
#  'to',
#  'buy',
#  'them',
#  'examples',
#  'of',
#  'this',
#  'type',
#  'of',
#  'product',
#  'include',
#  'software',
#  'for',
#  'pcs',
#  'such',
#  'as',
#  'databases',
#  'word',
#  'processors',
#  'drawing',
#  'packages',
#  'and',
#  'project',
#  'management',
#  'tools',
#  'by',
#  'a',
#  'particular',
#  'customer',
#  'a',
#  'software',
#  'contractor',
#  'develops',
#  'the',
#  'software',
#  'especially',
#  'for',
#  'that',
#  'customer',
#  'examples',
#  'of',
#  'this',
#  'type',
#  'of',
#  'software',
#  'include',
#  'control',
#  'systems',
#  'for',
#  'electronic',
#  'devices',
#  'systems',
#  'written',
#  'to',
#  'support',
#  'a',
#  'particular',
#  'business',
#  'process',
#  'and',
#  'air',
#  'traffic',
#  'control',
#  'systems',
#  'may',
#  'be',
#  'developed',
#  'for',
#  'a',
#  'particular',
#  'customer',
#  'or',
#  'may',
#  'be',
#  'developed',
#  'for',
#  'a',
#  'general',
#  'market',
#  'with',
#  'all',
#  'aspects',
#  'of',
#  'software',
#  'production',
#  'software',
#  'support',
#  'about',
#  'software',
#  'for',
#  'custom',
#  'products',
#  'the',
#  'specification',
#  'is',
#  'usually',
#  'developed',
#  'and',
#  'controlled',
#  'by',
#  'the',
#  'engineering',
#  'organisation',
#  'that',
#  'is',
#  'buying',
#  'the',
#  'software',
#  'the',
#  'software',
#  'developers',
#  'must',
#  'work',
#  'to',
#  'that',
#  'specification',
#  'however',
#  'the',
#  'line',
#  'between',
#  'these',
#  'types',
#  'of',
#  'products',
#  'is',
#  'becoming',
#  'increasingly',
#  'blurred',
#  'more',
#  'and',
#  'more',
#  'software',
#  'companies',
#  'are',
#  'starting',
#  'with',
#  'a',
#  'generic',
#  'system',
#  'and',
#  'customising',
#  'it',
#  'to',
#  'the',
#  'needs',
#  'of',
#  'a',
#  'particular',
#  'customer',
#  'enterprise',
#  'resource',
#  'planning',
#  'erp',
#  'systems',
#  'such',
#  'as',
#  'the',
#  'sap',
#  'system',
#  'are',
#  'the',
#  'best',
#  'examples',
#  'of',
#  'this',
#  'approach',
#  'here',
#  'a',
#  'large',
#  'and',
#  'complex',
#  'system',
#  'is',
#  'adapted',
#  'for',
#  'a',
#  'company',
#  'by',
#  'incorporating',
#  'information',
#  'about',
#  'business',
#  'rules',
#  'and',
#  'processes',
#  'reports',
#  'required',
#  'and',
#  'so',
#  'on',
#  'software',
#  'engineering',
#  'is',
#  'an',
#  'engineering',
#  'discipline',
#  'that',
#  'is',
#  'concerned',
#  'with',
#  'all',
#  'aspects',
#  'of',
#  'software',
#  'production',
#  'from',
#  'the',
#  'early',
#  'stages',
#  'of',
#  'system',
#  'specification',
#  'to',
#  'maintaining',
#  'the',
#  'system',
#  'after',
#  'it',
#  'has',
#  'gone',
#  'into',
#  ...]

# %% [markdown]
# ### Plotting the frequency of words without removing stopwords

# %%
#Plotting Frequency Distribution before removing stopwords
freq = nltk.FreqDist(tokens)
plt.figure(figsize=(12,5))
freq.plot(40, cumulative=False)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## Removing the stopwords

# %% [markdown]
# ### Removing stopwords

# %%
#Removing Stopwords
stop_words =set(stopwords.words('english'))
filtered_tokens =[w for w in tokens if w not in stop_words]
tokens = filtered_tokens
finalText = " "
finalText = finalText.join(tokens)

# %% [markdown]
# ### Generating and plotting the WordCloud without stopwords

# %%
#Generating wordcloud after removing stopwords
wordcloud = WordCloud(stopwords={}, background_color='black').generate(finalText)

plt.figure(figsize = (10,10), facecolor = 'black') 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 3) 
plt.show()

# %% [markdown]
# ### Words frequency plot after removing stopwords

# %%
#Plotting Frequency Distribution after removing stopwords
tokens = nltk.word_tokenize(finalText)
freq = nltk.FreqDist(tokens)
plt.figure(figsize=(12,5))
freq.plot(40, cumulative=False)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### Plot of word length and frequency

# %%
#Plotting relationship between Word Length and Frequency
wordLen = [len(w) for w in tokens]
plt.hist(wordLen, bins=np.linspace(0,15))

plt.xlabel('Word length')
plt.ylabel('Frequency')
plt.title('Word length vs Frequency')
plt.show()

# %% [markdown]
# ## POS Tagging

# %% [markdown]
# ### Perform POS Tagging

# %%
#POS Tagging
postTag = nltk.pos_tag(tokens)
postTag
# Out:
# [('objectives', 'NNS'),
#  ('objectives', 'VBZ'),
#  ('chapter', 'NN'),
#  ('introduce', 'NN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('provide', 'NN'),
#  ('framework', 'NN'),
#  ('understanding', 'VBG'),
#  ('rest', 'JJ'),
#  ('book', 'NN'),
#  ('read', 'VBP'),
#  ('chapter', 'NN'),
#  ('understand', 'NN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('important', 'JJ'),
#  ('know', 'VBP'),
#  ('answers', 'NNS'),
#  ('key', 'JJ'),
#  ('questions', 'NNS'),
#  ('provide', 'VBP'),
#  ('introduction', 'NN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('understand', 'JJ'),
#  ('ethical', 'JJ'),
#  ('professional', 'NN'),
#  ('issues', 'NNS'),
#  ('important', 'JJ'),
#  ('software', 'NN'),
#  ('engineers', 'NNS'),
#  ('contents', 'NNS'),
#  ('virtually', 'RB'),
#  ('countries', 'NNS'),
#  ('depend', 'VBP'),
#  ('complex', 'JJ'),
#  ('computerbased', 'VBN'),
#  ('systems', 'NNS'),
#  ('national', 'JJ'),
#  ('infrastructures', 'NNS'),
#  ('utilities', 'NNS'),
#  ('rely', 'VBP'),
#  ('computerbased', 'JJ'),
#  ('systems', 'NNS'),
#  ('electrical', 'JJ'),
#  ('products', 'NNS'),
#  ('include', 'VBP'),
#  ('computer', 'NN'),
#  ('controlling', 'VBG'),
#  ('software', 'NN'),
#  ('industrial', 'JJ'),
#  ('manufacturing', 'NN'),
#  ('distribution', 'NN'),
#  ('completely', 'RB'),
#  ('computerised', 'VBN'),
#  ('financial', 'JJ'),
#  ('system', 'NN'),
#  ('therefore', 'IN'),
#  ('producing', 'VBG'),
#  ('maintaining', 'VBG'),
#  ('software', 'NN'),
#  ('costeffectively', 'RB'),
#  ('essential', 'JJ'),
#  ('functioning', 'VBG'),
#  ('national', 'JJ'),
#  ('international', 'JJ'),
#  ('economies', 'NNS'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('engineering', 'NN'),
#  ('discipline', 'NN'),
#  ('whose', 'WP$'),
#  ('focus', 'NN'),
#  ('costeffective', 'JJ'),
#  ('development', 'NN'),
#  ('highquality', 'NN'),
#  ('software', 'NN'),
#  ('systems', 'NNS'),
#  ('software', 'NN'),
#  ('abstract', 'JJ'),
#  ('intangible', 'JJ'),
#  ('constrained', 'VBN'),
#  ('materials', 'NNS'),
#  ('governed', 'VBD'),
#  ('physical', 'JJ'),
#  ('laws', 'NNS'),
#  ('manufacturing', 'VBG'),
#  ('processes', 'NNS'),
#  ('ways', 'NNS'),
#  ('simplifies', 'NNS'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('physical', 'JJ'),
#  ('limitations', 'NNS'),
#  ('potential', 'JJ'),
#  ('software', 'NN'),
#  ('however', 'RB'),
#  ('lack', 'RB'),
#  ('natural', 'JJ'),
#  ('constraints', 'NNS'),
#  ('means', 'VBZ'),
#  ('software', 'NN'),
#  ('easily', 'RB'),
#  ('become', 'VB'),
#  ('extremely', 'RB'),
#  ('complex', 'JJ'),
#  ('hence', 'NN'),
#  ('difficult', 'JJ'),
#  ('understand', 'JJ'),
#  ('notion', 'NN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('first', 'RB'),
#  ('proposed', 'VBD'),
#  ('1968', 'CD'),
#  ('conference', 'NN'),
#  ('held', 'VBD'),
#  ('discuss', 'NN'),
#  ('called', 'VBN'),
#  ('software', 'NN'),
#  ('crisis', 'NN'),
#  ('software', 'NN'),
#  ('crisis', 'NN'),
#  ('resulted', 'VBD'),
#  ('directly', 'RB'),
#  ('introduction', 'JJ'),
#  ('new', 'JJ'),
#  ('computer', 'NN'),
#  ('hardware', 'NN'),
#  ('based', 'VBN'),
#  ('integrated', 'VBN'),
#  ('circuits', 'NNS'),
#  ('power', 'NN'),
#  ('made', 'VBD'),
#  ('hitherto', 'NN'),
#  ('unrealisable', 'JJ'),
#  ('computer', 'NN'),
#  ('applications', 'NNS'),
#  ('feasible', 'JJ'),
#  ('proposition', 'NN'),
#  ('resulting', 'VBG'),
#  ('software', 'NN'),
#  ('orders', 'NNS'),
#  ('magnitude', 'VBP'),
#  ('larger', 'JJR'),
#  ('complex', 'JJ'),
#  ('previous', 'JJ'),
#  ('software', 'NN'),
#  ('systems', 'NNS'),
#  ('early', 'JJ'),
#  ('experience', 'NN'),
#  ('building', 'NN'),
#  ('systems', 'NNS'),
#  ('showed', 'VBD'),
#  ('informal', 'JJ'),
#  ('software', 'NN'),
#  ('development', 'NN'),
#  ('good', 'VBD'),
#  ('enough', 'RB'),
#  ('major', 'JJ'),
#  ('projects', 'NNS'),
#  ('sometimes', 'RB'),
#  ('years', 'NNS'),
#  ('late', 'JJ'),
#  ('software', 'NN'),
#  ('cost', 'NN'),
#  ('much', 'RB'),
#  ('predicted', 'VBD'),
#  ('unreliable', 'JJ'),
#  ('difficult', 'JJ'),
#  ('maintain', 'NN'),
#  ('performed', 'VBD'),
#  ('poorly', 'RB'),
#  ('software', 'NN'),
#  ('development', 'NN'),
#  ('crisis', 'NN'),
#  ('hardware', 'NN'),
#  ('costs', 'NNS'),
#  ('tumbling', 'VBG'),
#  ('whilst', 'JJ'),
#  ('software', 'NN'),
#  ('costs', 'NNS'),
#  ('rising', 'VBG'),
#  ('rapidly', 'RB'),
#  ('new', 'JJ'),
#  ('techniques', 'NNS'),
#  ('methods', 'NNS'),
#  ('needed', 'VBN'),
#  ('control', 'NN'),
#  ('complexity', 'NN'),
#  ('inherent', 'JJ'),
#  ('large', 'JJ'),
#  ('software', 'NN'),
#  ('systems', 'NNS'),
#  ('techniques', 'VBZ'),
#  ('become', 'JJ'),
#  ('part', 'NN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('widely', 'RB'),
#  ('used', 'VBN'),
#  ('however', 'RB'),
#  ('ability', 'NN'),
#  ('produce', 'VBP'),
#  ('software', 'NN'),
#  ('increased', 'VBN'),
#  ('complexity', 'NN'),
#  ('software', 'NN'),
#  ('systems', 'NNS'),
#  ('need', 'VBP'),
#  ('new', 'JJ'),
#  ('technologies', 'NNS'),
#  ('resulting', 'VBG'),
#  ('convergence', 'NN'),
#  ('computers', 'NNS'),
#  ('communication', 'VBP'),
#  ('systems', 'NNS'),
#  ('complex', 'JJ'),
#  ('graphical', 'JJ'),
#  ('user', 'NN'),
#  ('interfaces', 'NNS'),
#  ('place', 'VBP'),
#  ('new', 'JJ'),
#  ('demands', 'NNS'),
#  ('software', 'NN'),
#  ('engineers', 'NNS'),
#  ('many', 'JJ'),
#  ('companies', 'NNS'),
#  ('still', 'RB'),
#  ('apply', 'VBP'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('techniques', 'NNS'),
#  ('effectively', 'RB'),
#  ('many', 'JJ'),
#  ('projects', 'NNS'),
#  ('still', 'RB'),
#  ('produce', 'VBP'),
#  ('software', 'NN'),
#  ('unreliable', 'JJ'),
#  ('delivered', 'VBN'),
#  ('late', 'JJ'),
#  ('budget', 'NN'),
#  ('think', 'NN'),
#  ('made', 'VBD'),
#  ('tremendous', 'JJ'),
#  ('progress', 'NN'),
#  ('since', 'IN'),
#  ('1968', 'CD'),
#  ('development', 'NN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('markedly', 'RB'),
#  ('improved', 'VBD'),
#  ('software', 'NN'),
#  ('much', 'RB'),
#  ('better', 'RBR'),
#  ('understanding', 'JJ'),
#  ('activities', 'NNS'),
#  ('involved', 'VBN'),
#  ('software', 'NN'),
#  ('development', 'NN'),
#  ('developed', 'VBD'),
#  ('effective', 'JJ'),
#  ('methods', 'NNS'),
#  ('software', 'NN'),
#  ('specification', 'NN'),
#  ('design', 'NN'),
#  ('implementation', 'NN'),
#  ('new', 'JJ'),
#  ('notations', 'NNS'),
#  ('tools', 'NNS'),
#  ('reduce', 'VB'),
#  ('effort', 'NN'),
#  ('required', 'VBN'),
#  ('produce', 'VBP'),
#  ('large', 'JJ'),
#  ('complex', 'JJ'),
#  ('systems', 'NNS'),
#  ('know', 'VBP'),
#  ('single', 'JJ'),
#  ('ideal', 'JJ'),
#  ('approach', 'NN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('wide', 'JJ'),
#  ('diversity', 'NN'),
#  ('different', 'JJ'),
#  ('types', 'NNS'),
#  ('systems', 'NNS'),
#  ('organisations', 'NNS'),
#  ('use', 'VBP'),
#  ('systems', 'NNS'),
#  ('means', 'NNS'),
#  ('need', 'VBP'),
#  ('diversity', 'NN'),
#  ('approaches', 'NNS'),
#  ('software', 'NN'),
#  ('development', 'NN'),
#  ('however', 'RB'),
#  ('fundamental', 'JJ'),
#  ('notions', 'NNS'),
#  ('process', 'NN'),
#  ('system', 'NN'),
#  ('organisation', 'NN'),
#  ('underlie', 'IN'),
#  ('techniques', 'NNS'),
#  ('essence', 'NN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('software', 'NN'),
#  ('engineers', 'NNS'),
#  ('rightly', 'RB'),
#  ('proud', 'JJ'),
#  ('achievements', 'NNS'),
#  ('without', 'IN'),
#  ('complex', 'JJ'),
#  ('software', 'NN'),
#  ('would', 'MD'),
#  ('explored', 'VB'),
#  ('space', 'NN'),
#  ('would', 'MD'),
#  ('internet', 'VB'),
#  ('modern', 'JJ'),
#  ('telecommunications', 'NNS'),
#  ('forms', 'NNS'),
#  ('travel', 'VBP'),
#  ('would', 'MD'),
#  ('dangerous', 'VB'),
#  ('expensive', 'JJ'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('contributed', 'VBD'),
#  ('great', 'JJ'),
#  ('deal', 'NN'),
#  ('convinced', 'VBN'),
#  ('discipline', 'NN'),
#  ('matures', 'VBZ'),
#  ('contributions', 'NNS'),
#  ('21st', 'JJ'),
#  ('century', 'NN'),
#  ('even', 'RB'),
#  ('greater', 'JJR'),
#  ('section', 'NN'),
#  ('designed', 'VBN'),
#  ('answer', 'IN'),
#  ('fundamental', 'JJ'),
#  ('questions', 'NNS'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('give', 'JJ'),
#  ('impression', 'NN'),
#  ('views', 'NNS'),
#  ('discipline', 'VBP'),
#  ('format', 'NN'),
#  ('used', 'VBN'),
#  ('faq', 'RBR'),
#  ('frequently', 'RB'),
#  ('asked', 'VBN'),
#  ('questions', 'NNS'),
#  ('list', 'VBP'),
#  ('approach', 'NN'),
#  ('commonly', 'RB'),
#  ('used', 'VBD'),
#  ('internet', 'NN'),
#  ('newsgroups', 'NNS'),
#  ('provide', 'VBP'),
#  ('newcomers', 'NNS'),
#  ('answers', 'NNS'),
#  ('frequently', 'RB'),
#  ('asked', 'VBD'),
#  ('questions', 'NNS'),
#  ('think', 'VBP'),
#  ('effective', 'JJ'),
#  ('way', 'NN'),
#  ('give', 'VBP'),
#  ('succinct', 'JJ'),
#  ('introduction', 'NN'),
#  ('subject', 'JJ'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('figure', 'NN'),
#  ('many', 'JJ'),
#  ('people', 'NNS'),
#  ('equate', 'VBP'),
#  ('term', 'NN'),
#  ('software', 'NN'),
#  ('computer', 'NN'),
#  ('programs', 'NNS'),
#  ('however', 'RB'),
#  ('prefer', 'VBP'),
#  ('broader', 'JJR'),
#  ('definition', 'NN'),
#  ('software', 'NN'),
#  ('programs', 'NNS'),
#  ('also', 'RB'),
#  ('associated', 'VBN'),
#  ('documentation', 'NN'),
#  ('configuration', 'NN'),
#  ('data', 'NNS'),
#  ('needed', 'VBD'),
#  ('make', 'NN'),
#  ('programs', 'NNS'),
#  ('operate', 'VBP'),
#  ('correctly', 'RB'),
#  ('software', 'NN'),
#  ('system', 'NN'),
#  ('usually', 'RB'),
#  ('consists', 'VBZ'),
#  ('number', 'NN'),
#  ('separate', 'JJ'),
#  ('programs', 'NNS'),
#  ('configuration', 'NN'),
#  ('files', 'NNS'),
#  ('used', 'VBN'),
#  ('set', 'VBN'),
#  ('programs', 'NNS'),
#  ('system', 'NN'),
#  ('documentation', 'NN'),
#  ('describes', 'VBZ'),
#  ('structure', 'NN'),
#  ('system', 'NN'),
#  ('user', 'JJ'),
#  ('documentation', 'NN'),
#  ('explains', 'NNS'),
#  ('use', 'VBP'),
#  ('system', 'NN'),
#  ('web', 'NN'),
#  ('sites', 'VBZ'),
#  ('users', 'NNS'),
#  ('download', 'JJ'),
#  ('recent', 'JJ'),
#  ('product', 'NN'),
#  ('information', 'NN'),
#  ('software', 'NN'),
#  ('engineers', 'NNS'),
#  ('concerned', 'JJ'),
#  ('developing', 'VBG'),
#  ('software', 'NN'),
#  ('products', 'NNS'),
#  ('ie', 'VBP'),
#  ('software', 'NN'),
#  ('sold', 'VBN'),
#  ('customer', 'NN'),
#  ('two', 'CD'),
#  ('fundamental', 'JJ'),
#  ('types', 'NNS'),
#  ('software', 'NN'),
#  ('product', 'NN'),
#  ('buy', 'VB'),
#  ('examples', 'NNS'),
#  ('type', 'JJ'),
#  ('product', 'NN'),
#  ('include', 'VBP'),
#  ('software', 'NN'),
#  ('pcs', 'JJ'),
#  ('databases', 'VBZ'),
#  ('word', 'NN'),
#  ('processors', 'NNS'),
#  ('drawing', 'VBG'),
#  ('packages', 'NNS'),
#  ('project', 'VBP'),
#  ('management', 'NN'),
#  ('tools', 'NNS'),
#  ('particular', 'JJ'),
#  ('customer', 'NN'),
#  ('software', 'NN'),
#  ('contractor', 'NN'),
#  ('develops', 'VBZ'),
#  ('software', 'NN'),
#  ('especially', 'RB'),
#  ('customer', 'NN'),
#  ('examples', 'NNS'),
#  ('type', 'VBP'),
#  ('software', 'NN'),
#  ('include', 'VBP'),
#  ('control', 'NN'),
#  ('systems', 'NNS'),
#  ('electronic', 'JJ'),
#  ('devices', 'NNS'),
#  ('systems', 'NNS'),
#  ('written', 'VBN'),
#  ('support', 'JJ'),
#  ('particular', 'JJ'),
#  ('business', 'NN'),
#  ('process', 'NN'),
#  ('air', 'NN'),
#  ('traffic', 'NN'),
#  ('control', 'NN'),
#  ('systems', 'NNS'),
#  ('may', 'MD'),
#  ('developed', 'VB'),
#  ('particular', 'JJ'),
#  ('customer', 'NN'),
#  ('may', 'MD'),
#  ('developed', 'VB'),
#  ('general', 'JJ'),
#  ('market', 'NN'),
#  ('aspects', 'NNS'),
#  ('software', 'NN'),
#  ('production', 'NN'),
#  ('software', 'NN'),
#  ('support', 'NN'),
#  ('software', 'NN'),
#  ('custom', 'NN'),
#  ('products', 'NNS'),
#  ('specification', 'NN'),
#  ('usually', 'RB'),
#  ('developed', 'VBD'),
#  ('controlled', 'JJ'),
#  ('engineering', 'NN'),
#  ('organisation', 'NN'),
#  ('buying', 'NN'),
#  ('software', 'NN'),
#  ('software', 'NN'),
#  ('developers', 'NNS'),
#  ('must', 'MD'),
#  ('work', 'VB'),
#  ('specification', 'NN'),
#  ('however', 'RB'),
#  ('line', 'NN'),
#  ('types', 'NNS'),
#  ('products', 'NNS'),
#  ('becoming', 'VBG'),
#  ('increasingly', 'RB'),
#  ('blurred', 'VBN'),
#  ('software', 'NN'),
#  ('companies', 'NNS'),
#  ('starting', 'VBG'),
#  ('generic', 'JJ'),
#  ('system', 'NN'),
#  ('customising', 'VBG'),
#  ('needs', 'NNS'),
#  ('particular', 'JJ'),
#  ('customer', 'NN'),
#  ('enterprise', 'NN'),
#  ('resource', 'NN'),
#  ('planning', 'NN'),
#  ('erp', 'JJ'),
#  ('systems', 'NNS'),
#  ('sap', 'JJ'),
#  ('system', 'NN'),
#  ('best', 'JJS'),
#  ('examples', 'NNS'),
#  ('approach', 'VBP'),
#  ('large', 'JJ'),
#  ('complex', 'JJ'),
#  ('system', 'NN'),
#  ('adapted', 'VBN'),
#  ('company', 'NN'),
#  ('incorporating', 'VBG'),
#  ('information', 'NN'),
#  ('business', 'NN'),
#  ('rules', 'NNS'),
#  ('processes', 'VBZ'),
#  ('reports', 'NNS'),
#  ('required', 'VBD'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('engineering', 'NN'),
#  ('discipline', 'NN'),
#  ('concerned', 'VBN'),
#  ('aspects', 'NNS'),
#  ('software', 'NN'),
#  ('production', 'NN'),
#  ('early', 'JJ'),
#  ('stages', 'NNS'),
#  ('system', 'NN'),
#  ('specification', 'NN'),
#  ('maintaining', 'VBG'),
#  ('system', 'NN'),
#  ('gone', 'VBN'),
#  ('use', 'JJ'),
#  ('definition', 'NN'),
#  ('two', 'CD'),
#  ('key', 'NN'),
#  ('phrases', 'NNS'),
#  ('try', 'VBP'),
#  ('discover', 'JJ'),
#  ('solutions', 'NNS'),
#  ('problems', 'NNS'),
#  ('even', 'RB'),
#  ('applicable', 'JJ'),
#  ('theories', 'NNS'),
#  ('methods', 'NNS'),
#  ('engineers', 'NNS'),
#  ('also', 'RB'),
#  ('recognise', 'VBP'),
#  ('must', 'MD'),
#  ('work', 'VB'),
#  ('organisational', 'JJ'),
#  ('financial', 'JJ'),
#  ('constraints', 'NNS'),
#  ('look', 'VBP'),
#  ('solutions', 'NNS'),
#  ('within', 'IN'),
#  ('constraints', 'NNS'),
#  ('technical', 'JJ'),
#  ('processes', 'NNS'),
#  ('software', 'NN'),
#  ('development', 'NN'),
#  ('also', 'RB'),
#  ('activities', 'NNS'),
#  ('software', 'NN'),
#  ('project', 'NN'),
#  ('management', 'NN'),
#  ('development', 'NN'),
#  ('tools', 'NNS'),
#  ('methods', 'NNS'),
#  ('theories', 'NNS'),
#  ('support', 'NN'),
#  ('software', 'NN'),
#  ('production', 'NN'),
#  ('general', 'JJ'),
#  ('software', 'NN'),
#  ('engineers', 'NNS'),
#  ('adopt', 'VBP'),
#  ('systematic', 'JJ'),
#  ('organised', 'JJ'),
#  ('approach', 'NN'),
#  ('work', 'NN'),
#  ('often', 'RB'),
#  ('effective', 'JJ'),
#  ('way', 'NN'),
#  ('produce', 'VBP'),
#  ('highquality', 'NN'),
#  ('software', 'NN'),
#  ('however', 'RB'),
#  ('engineering', 'NN'),
#  ('selecting', 'VBG'),
#  ('appropriate', 'JJ'),
#  ('method', 'NN'),
#  ('set', 'VBN'),
#  ('circumstances', 'NNS'),
#  ('creative', 'JJ'),
#  ('less', 'RBR'),
#  ('formal', 'JJ'),
#  ('approach', 'NN'),
#  ('development', 'NN'),
#  ('may', 'MD'),
#  ('effective', 'JJ'),
#  ('circumstances', 'NNS'),
#  ('less', 'RBR'),
#  ('formal', 'JJ'),
#  ('development', 'NN'),
#  ('particularly', 'RB'),
#  ('appropriate', 'JJ'),
#  ('development', 'NN'),
#  ('webbased', 'VBD'),
#  ('systems', 'NNS'),
#  ('requires', 'VBZ'),
#  ('blend', 'JJ'),
#  ('software', 'NN'),
#  ('graphical', 'JJ'),
#  ('design', 'NN'),
#  ('skills', 'NNS'),
#  ('computer', 'NN'),
#  ('science', 'NN'),
#  ('essentially', 'RB'),
#  ('computer', 'NN'),
#  ('science', 'NN'),
#  ('concerned', 'JJ'),
#  ('theories', 'NNS'),
#  ('methods', 'NNS'),
#  ('underlie', 'JJ'),
#  ('computers', 'NNS'),
#  ('software', 'NN'),
#  ('systems', 'NNS'),
#  ('whereas', 'WDT'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('concerned', 'JJ'),
#  ('practical', 'JJ'),
#  ('problems', 'NNS'),
#  ('producing', 'VBG'),
#  ('software', 'NN'),
#  ('knowledge', 'NN'),
#  ('computer', 'NN'),
#  ('science', 'NN'),
#  ('essential', 'JJ'),
#  ('software', 'NN'),
#  ('engineers', 'NNS'),
#  ('way', 'NN'),
#  ('knowledge', 'VBP'),
#  ('physics', 'NNS'),
#  ('essential', 'JJ'),
#  ('electrical', 'JJ'),
#  ('engineers', 'NNS'),
#  ('ideally', 'RB'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('underpinned', 'JJ'),
#  ('theories', 'NNS'),
#  ('computer', 'NN'),
#  ('science', 'NN'),
#  ('reality', 'NN'),
#  ('case', 'NN'),
#  ('software', 'NN'),
#  ('engineers', 'NNS'),
#  ('must', 'MD'),
#  ('often', 'RB'),
#  ('use', 'VB'),
#  ('ad', 'NN'),
#  ('hoc', 'NN'),
#  ('approaches', 'NNS'),
#  ('developing', 'VBG'),
#  ('software', 'NN'),
#  ('elegant', 'JJ'),
#  ('theories', 'NNS'),
#  ('computer', 'NN'),
#  ('science', 'NN'),
#  ('always', 'RB'),
#  ('applied', 'VBD'),
#  ('real', 'JJ'),
#  ('complex', 'JJ'),
#  ('problems', 'NNS'),
#  ('require', 'VBP'),
#  ('software', 'NN'),
#  ('solution', 'NN'),
#  ('engineering', 'NN'),
#  ('system', 'NN'),
#  ('engineering', 'NN'),
#  ('concerned', 'JJ'),
#  ('aspects', 'NNS'),
#  ('development', 'NN'),
#  ('evolution', 'NN'),
#  ('complex', 'JJ'),
#  ('systems', 'NNS'),
#  ('software', 'NN'),
#  ('plays', 'VBZ'),
#  ('major', 'JJ'),
#  ('role', 'NN'),
#  ('system', 'NN'),
#  ('engineering', 'NN'),
#  ('therefore', 'RB'),
#  ('concerned', 'JJ'),
#  ('hardware', 'NN'),
#  ('development', 'NN'),
#  ('policy', 'NN'),
#  ('process', 'NN'),
#  ('design', 'NN'),
#  ('system', 'NN'),
#  ('deployment', 'NN'),
#  ('well', 'RB'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('system', 'NN'),
#  ('engineers', 'NNS'),
#  ('involved', 'VBN'),
#  ('specifying', 'VBG'),
#  ('system', 'NN'),
#  ('defining', 'VBG'),
#  ('overall', 'JJ'),
#  ('architecture', 'NN'),
#  ('integrating', 'VBG'),
#  ('different', 'JJ'),
#  ('parts', 'NNS'),
#  ('create', 'VBP'),
#  ('finished', 'VBN'),
#  ('system', 'NN'),
#  ('less', 'RBR'),
#  ('concerned', 'JJ'),
#  ('engineering', 'NN'),
#  ('system', 'NN'),
#  ('components', 'NNS'),
#  ('hardware', 'NN'),
#  ('software', 'NN'),
#  ('etc', 'JJ'),
#  ('system', 'NN'),
#  ('engineering', 'NN'),
#  ('older', 'JJR'),
#  ('discipline', 'NN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('people', 'NNS'),
#  ('specifying', 'VBG'),
#  ('assembling', 'VBG'),
#  ('complex', 'JJ'),
#  ('industrial', 'JJ'),
#  ('systems', 'NNS'),
#  ('aircraft', 'JJ'),
#  ('chemical', 'JJ'),
#  ('plants', 'NNS'),
#  ('hundred', 'CD'),
#  ('years', 'NNS'),
#  ('however', 'RB'),
#  ('percentage', 'NN'),
#  ('software', 'NN'),
#  ('systems', 'NNS'),
#  ('increased', 'VBD'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('techniques', 'NNS'),
#  ('usecase', 'JJ'),
#  ('modelling', 'VBG'),
#  ('configuration', 'NN'),
#  ('management', 'NN'),
#  ('used', 'VBN'),
#  ('systems', 'NNS'),
#  ('engineering', 'NN'),
#  ('process', 'NN'),
#  ('discuss', 'NN'),
#  ('system', 'NN'),
#  ('engineering', 'NN'),
#  ('chapter', 'NN'),
#  ('2', 'CD'),
#  ('software', 'NN'),
#  ('process', 'NN'),
#  ('set', 'VBN'),
#  ('activities', 'NNS'),
#  ('associated', 'VBN'),
#  ('results', 'NNS'),
#  ('produce', 'VBP'),
#  ('software', 'NN'),
#  ('product', 'NN'),
#  ('four', 'CD'),
#  ('fundamental', 'JJ'),
#  ('process', 'NN'),
#  ('activities', 'NNS'),
#  ('covered', 'VBD'),
#  ('later', 'RBR'),
#  ('book', 'NN'),
#  ('common', 'JJ'),
#  ('software', 'NN'),
#  ('processes', 'VBZ'),
#  ('produced', 'JJ'),
#  ('constraints', 'NNS'),
#  ('operation', 'NN'),
#  ('customer', 'NN'),
#  ('requires', 'VBZ'),
#  ('different', 'JJ'),
#  ('types', 'NNS'),
#  ('systems', 'NNS'),
#  ('need', 'VBP'),
#  ('different', 'JJ'),
#  ('development', 'NN'),
#  ('processes', 'VBZ'),
#  ('example', 'NN'),
#  ('realtime', 'NN'),
#  ('software', 'NN'),
#  ('aircraft', 'NN'),
#  ('completely', 'RB'),
#  ('specified', 'VBN'),
#  ('development', 'NN'),
#  ('begins', 'VBZ'),
#  ('whereas', 'JJ'),
#  ('ecommerce', 'NN'),
#  ('systems', 'NNS'),
#  ('specification', 'JJ'),
#  ('program', 'NN'),
#  ('usually', 'RB'),
#  ('developed', 'VBD'),
#  ('together', 'RB'),
#  ('consequently', 'RB'),
#  ('generic', 'JJ'),
#  ('activities', 'NNS'),
#  ('may', 'MD'),
#  ('organised', 'VB'),
#  ('different', 'JJ'),
#  ('ways', 'NNS'),
#  ('described', 'VBN'),
#  ('different', 'JJ'),
#  ('levels', 'NNS'),
#  ('detail', 'VBP'),
#  ('different', 'JJ'),
#  ('types', 'NNS'),
#  ('software', 'NN'),
#  ('however', 'RB'),
#  ('use', 'RB'),
#  ('inappropriate', 'JJ'),
#  ('software', 'NN'),
#  ('process', 'NN'),
#  ('may', 'MD'),
#  ('reduce', 'VB'),
#  ('quality', 'NN'),
#  ('usefulness', 'JJ'),
#  ('software', 'NN'),
#  ('product', 'NN'),
#  ('developed', 'VBD'),
#  ('andor', 'JJ'),
#  ('increase', 'NN'),
#  ('development', 'NN'),
#  ('costs', 'NNS'),
#  ('software', 'NN'),
#  ('processes', 'VBZ'),
#  ('discussed', 'JJ'),
#  ('detail', 'NN'),
#  ('chapter', 'NN'),
#  ('4', 'CD'),
#  ('important', 'JJ'),
#  ('topic', 'NN'),
#  ('software', 'NN'),
#  ('process', 'NN'),
#  ('improvement', 'NN'),
#  ('covered', 'VBD'),
#  ('chapter', 'NN'),
#  ('28', 'CD'),
#  ('software', 'NN'),
#  ('process', 'NN'),
#  ('model', 'NN'),
#  ('simplified', 'VBN'),
#  ('description', 'NN'),
#  ('software', 'NN'),
#  ('process', 'NN'),
#  ('presents', 'VBZ'),
#  ('one', 'CD'),
#  ('view', 'NN'),
#  ('process', 'NN'),
#  ('process', 'NN'),
#  ('models', 'NNS'),
#  ('may', 'MD'),
#  ('include', 'VB'),
#  ('activities', 'NNS'),
#  ('part', 'NN'),
#  ('software', 'NN'),
#  ('process', 'NN'),
#  ('software', 'NN'),
#  ('products', 'NNS'),
#  ('roles', 'VBZ'),
#  ('people', 'NNS'),
#  ('involved', 'VBN'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('examples', 'NNS'),
#  ('types', 'NNS'),
#  ('software', 'NN'),
#  ('process', 'NN'),
#  ('model', 'NN'),
#  ('may', 'MD'),
#  ('produced', 'VB'),
#  ('inputs', 'NNS'),
#  ('outputs', 'JJ'),
#  ('dependencies', 'NNS'),
#  ('activities', 'NNS'),
#  ('model', 'VBP'),
#  ('represent', 'JJ'),
#  ('human', 'JJ'),
#  ('actions', 'NNS'),
#  ('carries', 'VBZ'),
#  ('data', 'NNS'),
#  ('transformation', 'NN'),
#  ('shows', 'VBZ'),
#  ('input', 'NN'),
#  ('process', 'NN'),
#  ('specification', 'NN'),
#  ('transformed', 'VBD'),
#  ('output', 'NN'),
#  ('design', 'NN'),
#  ('activities', 'NNS'),
#  ('may', 'MD'),
#  ('represent', 'VB'),
#  ('transformations', 'NNS'),
#  ('carried', 'VBD'),
#  ('people', 'NNS'),
#  ('computers', 'NNS'),
#  ('software', 'NN'),
#  ('process', 'NN'),
#  ('models', 'NNS'),
#  ('based', 'VBN'),
#  ('one', 'CD'),
#  ('three', 'CD'),
#  ('general', 'JJ'),
#  ('models', 'NNS'),
#  ('paradigms', 'VBP'),
#  ('software', 'NN'),
#  ('development', 'NN'),
#  ('separate', 'JJ'),
#  ('process', 'NN'),
#  ('phases', 'VBZ'),
#  ('requirements', 'NNS'),
#  ('specification', 'NN'),
#  ('software', 'NN'),
#  ('design', 'NN'),
#  ('implementation', 'NN'),
#  ('testing', 'VBG'),
#  ('stage', 'NN'),
#  ('defined', 'VBD'),
#  ('signedoff', 'NN'),
#  ('development', 'NN'),
#  ('goes', 'VBZ'),
#  ('following', 'VBG'),
#  ('stage', 'NN'),
#  ('development', 'NN'),
#  ('validation', 'NN'),
#  ('initial', 'JJ'),
#  ('system', 'NN'),
#  ('rapidly', 'RB'),
#  ('developed', 'VBD'),
#  ('abstract', 'JJ'),
#  ('specifications', 'NNS'),
#  ('refined', 'VBN'),
#  ('customer', 'NN'),
#  ('input', 'NN'),
#  ('produce', 'VBP'),
#  ('system', 'NN'),
#  ('satisfies', 'VBZ'),
#  ('customers', 'NNS'),
#  ('needs', 'NNS'),
#  ('system', 'NN'),
#  ...]

# %% [markdown]
# ### Calculate the frequency and plot it

# %%
#Plotting Tag frequency
tagCount = Counter(tag for word, tag in postTag)
print(tagCount)
tagFreq = nltk.FreqDist(tagCount)
plt.figure(figsize=(12,5))
tagFreq.plot(40, cumulative=False)
# Out:
# Counter({'NN': 45417, 'NNS': 20459, 'JJ': 20113, 'VBP': 6246, 'RB': 5764, 'VBG': 4818, 'VBN': 4655, 'VBD': 4426, 'VB': 3253, 'VBZ': 3048, 'MD': 2415, 'CD': 2199, 'IN': 1034, 'JJR': 308, 'RBR': 204, 'DT': 173, 'NNP': 168, 'JJS': 157, 'FW': 138, 'CC': 100, 'RP': 44, 'PRP': 44, 'WP$': 32, 'RBS': 15, 'WDT': 14, 'WRB': 14, '$': 8, 'WP': 4, 'POS': 3, 'PRP$': 3, 'NNPS': 2, 'SYM': 1, 'EX': 1})
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
